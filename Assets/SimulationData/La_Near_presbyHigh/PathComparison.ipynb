# %%
# Imports
# json
import json
import os
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load JSON files
# Including the road network and vehicle data

# %%
# file names
network='network.json'
vehicles='La_PresbyHigh_50.json'

# %%
# load both json files
with open('network.json') as f:
    network = json.load(f)

# %%
vData=[]
with open(vehicles) as f:
    vData = json.load(f)

# %%
print(network)
# Out:
# {'segments': [{'segmentId': 0, 'waypoints': [{'x': -87.55889129638672, 'y': 5.197044372558594}, {'x': -52.70515823364258, 'y': 4.492088317871094}]}, {'segmentId': 1, 'waypoints': [{'x': -52.533302307128906, 'y': 7.788421630859375}, {'x': -87.85829162597656, 'y': 8.802352905273438}]}, {'segmentId': 2, 'waypoints': [{'x': -137.37481689453125, 'y': -83.18292999267578}, {'x': -118.69498443603516, 'y': -82.07202911376953}]}, {'segmentId': 3, 'waypoints': [{'x': -118.81755065917969, 'y': -80.06571960449219}, {'x': -136.93362426757812, 'y': -81.57896423339844}]}, {'segmentId': 4, 'waypoints': [{'x': -118.0108642578125, 'y': -82.60470581054688}, {'x': -124.74200439453125, 'y': -94.09397888183594}, {'x': -122.65049743652344, 'y': -94.58973693847656}, {'x': -115.56788635253906, 'y': -82.07726287841797}]}, {'segmentId': 5, 'waypoints': [{'x': -114.38159942626953, 'y': -81.30661010742188}, {'x': -96.27548217773438, 'y': -79.3378677368164}]}, {'segmentId': 6, 'waypoints': [{'x': -96.31712341308594, 'y': -77.09993743896484}, {'x': -114.08031463623047, 'y': -79.70855712890625}]}, {'segmentId': 7, 'waypoints': [{'x': -90.52909088134766, 'y': -78.39541625976562}, {'x': -52.844661712646484, 'y': -75.23406982421875}]}, {'segmentId': 8, 'waypoints': [{'x': -52.87962341308594, 'y': -73.35509490966797}, {'x': -90.00648498535156, 'y': -76.51480865478516}]}, {'segmentId': 9, 'waypoints': [{'x': -91.64571380615234, 'y': -75.13615417480469}, {'x': -89.29928588867188, 'y': 3.8766555786132812}]}, {'segmentId': 10, 'waypoints': [{'x': -93.37500762939453, 'y': 4.1773681640625}, {'x': -95.49430084228516, 'y': -75.68403625488281}]}, {'segmentId': 11, 'waypoints': [{'x': -95.08586120605469, 'y': -79.98014068603516}, {'x': -94.22554016113281, 'y': -85.24818420410156}, {'x': -96.72572326660156, 'y': -114.35936737060547}, {'x': -106.05657958984375, 'y': -125.04815673828125}]}, {'segmentId': 12, 'waypoints': [{'x': -102.47862243652344, 'y': -126.06448364257812}, {'x': -92.47109985351562, 'y': -114.88800048828125}, {'x': -89.5329360961914, 'y': -83.23715209960938}, {'x': -90.67938232421875, 'y': -79.4384994506836}]}, {'segmentId': 13, 'waypoints': [{'x': -119.26051330566406, 'y': -136.1038055419922}, {'x': -137.87469482421875, 'y': -128.7512969970703}, {'x': -139.38121032714844, 'y': -130.06077575683594}, {'x': -120.33650207519531, 'y': -137.14422607421875}]}, {'segmentId': 14, 'waypoints': [{'x': -118.06721496582031, 'y': -141.04446411132812}, {'x': -100.14860534667969, 'y': -147.64065551757812}, {'x': -99.28870391845703, 'y': -146.03126525878906}, {'x': -116.05024719238281, 'y': -139.6999969482422}]}, {'segmentId': 15, 'waypoints': [{'x': -51.2315673828125, 'y': 2.5879440307617188}, {'x': -51.67939758300781, 'y': -72.4085693359375}]}, {'segmentId': 16, 'waypoints': [{'x': -47.91094970703125, 'y': -72.42428588867188}, {'x': -47.34623336791992, 'y': 2.4457778930664062}]}, {'segmentId': 17, 'waypoints': [{'x': -51.701942443847656, 'y': -76.20600891113281}, {'x': -51.636512756347656, 'y': -120.01365661621094}]}, {'segmentId': 18, 'waypoints': [{'x': -47.41413116455078, 'y': -120.59217071533203}, {'x': -47.9453239440918, 'y': -75.81793212890625}]}, {'segmentId': 19, 'waypoints': [{'x': -52.54631423950195, 'y': -123.09049987792969}, {'x': -69.18206787109375, 'y': -138.9295654296875}]}, {'segmentId': 20, 'waypoints': [{'x': -66.62989807128906, 'y': -140.10218811035156}, {'x': -50.406490325927734, 'y': -124.68971252441406}]}, {'segmentId': 21, 'waypoints': [{'x': -71.4631576538086, 'y': -139.62210083007812}, {'x': -102.93754577636719, 'y': -128.47344970703125}]}, {'segmentId': 22, 'waypoints': [{'x': -105.12769317626953, 'y': -130.78759765625}, {'x': -73.79644012451172, 'y': -142.6564178466797}]}, {'segmentId': 23, 'waypoints': [{'x': -74.52517700195312, 'y': -143.51785278320312}, {'x': -78.32980346679688, 'y': -145.20166015625}, {'x': -67.66851806640625, 'y': -150.67529296875}, {'x': -65.3504867553711, 'y': -149.6319580078125}, {'x': -73.03521728515625, 'y': -145.06735 ...

# %%
print(vData)
# Out:
# [{'id': 0, 'path_norm': {'path': [{'id': 14, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 25, 'init_cost': 10.0, 'end_cost': 0.04830799996852875, 'init_density': 1.0, 'end_density': 2.0}, {'id': 12, 'init_cost': 48.0, 'end_cost': 0.008989389054477215, 'init_density': 3.0, 'end_density': 2.0}, {'id': 7, 'init_cost': 37.0, 'end_cost': 0.4591760039329529, 'init_density': 1.0, 'end_density': 4.0}, {'id': 16, 'init_cost': 74.0, 'end_cost': 0.18713143467903137, 'init_density': 1.0, 'end_density': 6.0}, {'id': 29, 'init_cost': 125.0, 'end_cost': 0.06137111410498619, 'init_density': 1.0, 'end_density': 5.0}], 'path_alt': []}, 'path_cav_init': {'path': [{'id': 14, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 25, 'init_cost': 10.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 22, 'init_cost': 33.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}, {'id': 20, 'init_cost': 22.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 30, 'init_cost': 131.0, 'end_cost': 0.0, 'init_density': 3.0, 'end_density': 0.0}, {'id': 29, 'init_cost': 125.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}], 'path_alt': []}, 'path_cav_end': {'path': [{'id': 14, 'init_cost': 2.0, 'end_cost': 0.05555781349539757, 'init_density': 1.0, 'end_density': 2.0}, {'id': 25, 'init_cost': 10.0, 'end_cost': 0.0092769181355834, 'init_density': 2.0, 'end_density': 2.0}, {'id': 22, 'init_cost': 33.0, 'end_cost': 0.028950881212949753, 'init_density': 1.0, 'end_density': 3.0}, {'id': 20, 'init_cost': 22.0, 'end_cost': 0.045022349804639816, 'init_density': 2.0, 'end_density': 4.0}, {'id': 18, 'init_cost': 44.0, 'end_cost': 0.056653719395399094, 'init_density': 2.0, 'end_density': 3.0}, {'id': 16, 'init_cost': 74.0, 'end_cost': 0.056557636708021164, 'init_density': 1.0, 'end_density': 3.0}, {'id': 29, 'init_cost': 125.0, 'end_cost': 0.0, 'init_density': 3.0, 'end_density': 0.0}], 'path_alt': []}, 'path_norm_segments': [], 'path_cav_init_segments': [], 'path_cav_end_segments': []}, {'id': 1, 'path_norm': {'path': [{'id': 21, 'init_cost': 33.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}, {'id': 12, 'init_cost': 48.0, 'end_cost': 0.019141530618071556, 'init_density': 1.0, 'end_density': 0.0}, {'id': 9, 'init_cost': 79.0, 'end_cost': 0.06833477318286896, 'init_density': 0.0, 'end_density': 3.0}, {'id': 10, 'init_cost': 79.0, 'end_cost': 0.09854681044816971, 'init_density': 0.0, 'end_density': 2.0}], 'path_alt': []}, 'path_cav_init': {'path': [{'id': 21, 'init_cost': 33.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}, {'id': 12, 'init_cost': 48.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 9, 'init_cost': 79.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}, {'id': 10, 'init_cost': 79.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}], 'path_alt': []}, 'path_cav_end': {'path': [{'id': 21, 'init_cost': 33.0, 'end_cost': 0.06829779595136642, 'init_density': 0.0, 'end_density': 3.0}, {'id': 6, 'init_cost': 17.0, 'end_cost': 0.01831095851957798, 'init_density': 0.0, 'end_density': 1.0}, {'id': 3, 'init_cost': 18.0, 'end_cost': 0.010440835729241371, 'init_density': 0.0, 'end_density': 1.0}, {'id': 27, 'init_cost': 96.0, 'end_cost': 0.17441199719905853, 'init_density': 0.0, 'end_density': 3.0}, {'id': 10, 'init_cost': 79.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}], 'path_alt': []}, 'path_norm_segments': [], 'path_cav_init_segments': [], 'path_cav_end_segments': []}, {'id': 2, 'path_norm': {'path': [{'id': 22, 'init_cost': 33.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 21, 'init_cost': 33.0, 'end_cost': 0.019141530618071556, 'init_density': 1.0, 'end_density': 1.0}, {'id': 12, 'init_cost': 48.0, 'end_cost': 0.019141530618071556, 'init_density': 3.0, 'end_density': 1.0}, {'id': 9, 'init_cost': 79.0, 'end_cost': 0.45914316177368164, 'init_density' ...

# %%
segments = network['segments']
waypoints = [segment['waypoints'] for segment in segments]

# %%
# dictionary of segments and waypoints
segments=network['segments']

# %%
def plotSegment(segment, segmentpath,color='b',c2='g'):
    # extract the waypoints
    waypoints = segment['waypoints']
    #init
    init_cost = segmentpath['init_cost']
    init_density = segmentpath['init_density']
    #end values
    end_cost = segmentpath['end_cost']
    end_density = segmentpath['end_density']
    # extract the coordinates of the waypoints
    coords = [(waypoint['x'], waypoint['y']) for waypoint in waypoints]
    # unpack the coordinates into two lists
    x, y = zip(*coords)
    
    # places the init cost and density
    # plt.text(x[0], y[0], f'Init Cost: {init_cost} \n', fontsize=8, ha='right',color=color)
    plt.text(x[0], y[0]+3, f'Init Density: {init_density}\n', fontsize=8, ha='right',color=color)
    # places the end cost and density
    # plt.text(x[-1], y[-1], f'End Cost: {end_cost}\n', fontsize=8, ha='left',color=c2)
    plt.text(x[-1], y[-1]+3, f'End Density: {end_density}\n', fontsize=8, ha='left',color=c2)
    
    # color
    
    
    # plot the segment
    plt.plot(x, y, 'b-', color=color)
    # plot the waypoints
    plt.plot(x, y, 'ro', color=color)

# %%
def plotPath(path,c,c2):
    for s in path:
        print(s)
        plotSegment(segments[s['id']],s,c,c2)

# %%
#  plot 2 paths

# %%
def plotPaths(p1,p2):
    plotPath(p1,'red','orange')
    plotPath(p2,'blue','green')
    
    # plt.show()

# %%
print(vData[0]['path_norm']['path'])
# Out:
# [{'id': 14, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}, {'id': 25, 'init_cost': 10.0, 'end_cost': 0.04830799996852875, 'init_density': 1.0, 'end_density': 2.0}, {'id': 12, 'init_cost': 48.0, 'end_cost': 0.008989389054477215, 'init_density': 3.0, 'end_density': 2.0}, {'id': 7, 'init_cost': 37.0, 'end_cost': 0.4591760039329529, 'init_density': 1.0, 'end_density': 4.0}, {'id': 16, 'init_cost': 74.0, 'end_cost': 0.18713143467903137, 'init_density': 1.0, 'end_density': 6.0}, {'id': 29, 'init_cost': 125.0, 'end_cost': 0.06137111410498619, 'init_density': 1.0, 'end_density': 5.0}]

# %%
plt.figure(figsize=(10, 10))

# %%
x_min=0
x_max=0
y_min=0
y_max=0
for segment_waypoints in waypoints:
    x_coords = [point['x'] for point in segment_waypoints]
    y_coords = [point['y'] for point in segment_waypoints]
    # Update the min and max values
    x_min = min(x_min, min(x_coords))
    x_max = max(x_max, max(x_coords))
    y_min = min(y_min, min(y_coords))
    y_max = max(y_max, max(y_coords))
    segment_id = "segment_" + str(segments[waypoints.index(segment_waypoints)]['segmentId'])
    plt.plot(x_coords, y_coords, marker='o', label=segment_id)
    plt.plot(x_coords, y_coords, marker='o')
    mid_x = sum(x_coords) / len(x_coords)
    mid_y = sum(y_coords) / len(y_coords)
    plt.text(mid_x, mid_y, segment_id, fontsize=8, ha='center', va='center', color='red')
plt.title('Road Network Map')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.show()

# %%
plt.xlim(x_min-10, x_max+10)
plt.ylim(y_min-10, y_max+10)
# Out:
# (-160.67529296875, 20.223785400390625)

# %% [markdown]
# # Vehicle Analysis

# %%
vehicleNum=28

# %%
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plotPath(vData[vehicleNum]['path_norm']['path'],'red','orange')
# Out:
# {'id': 23, 'init_cost': 3.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}
# {'id': 21, 'init_cost': 33.0, 'end_cost': 0.015661252662539482, 'init_density': 0.0, 'end_density': 0.0}
# {'id': 12, 'init_cost': 48.0, 'end_cost': 0.022471021860837936, 'init_density': 3.0, 'end_density': 1.0}
# {'id': 6, 'init_cost': 17.0, 'end_cost': 0.4585030972957611, 'init_density': 1.0, 'end_density': 3.0}
# {'id': 4, 'init_cost': 2.0, 'end_cost': 0.018513336777687073, 'init_density': 1.0, 'end_density': 1.0}
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', color=color)
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', color=color)

# %%
#metric total costg and density, initial vs end
# init cost and density
init_cost=[]
init_density=[]
# end cost and density
end_cost=[]
end_density=[]

for i in vData[vehicleNum]['path_norm']['path']:
    init_cost.append(i['init_cost'])
    init_density.append(i['init_density'])
    end_cost.append(i['end_cost'])
    end_density.append(i['end_density'])

# %%
total_init_cost=0
total_init_density=0
total_end_cost=0
total_end_density=0
total_init_cost = sum(init_cost)
total_init_density = sum(init_density)
total_end_cost = sum(end_cost)
total_end_density = sum(end_density)

norm_table=pd.DataFrame({
    "State": ["Initial", "Final"],
    "Cost":[total_init_cost,total_end_cost],
    "Density":[total_init_density,total_end_density]
})
#print table
print(norm_table)
# Out:
#      State        Cost  Density
# 0  Initial  103.000000      5.0
# 1    Final    0.515149      5.0

# %%
## cav

# %%
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plotPaths(vData[vehicleNum]['path_cav_init']['path'],vData[vehicleNum]['path_cav_end']['path'])
# Out:
# {'id': 23, 'init_cost': 3.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}
# {'id': 21, 'init_cost': 33.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}
# {'id': 12, 'init_cost': 48.0, 'end_cost': 0.0, 'init_density': 2.0, 'end_density': 0.0}
# {'id': 6, 'init_cost': 17.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}
# {'id': 4, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}
# {'id': 23, 'init_cost': 3.0, 'end_cost': 0.022577127441763878, 'init_density': 0.0, 'end_density': 1.0}
# {'id': 12, 'init_cost': 48.0, 'end_cost': 0.2668083906173706, 'init_density': 1.0, 'end_density': 3.0}
# {'id': 6, 'init_cost': 17.0, 'end_cost': 0.026082603260874748, 'init_density': 0.0, 'end_density': 2.0}
# {'id': 4, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 4.0, 'end_density': 0.0}
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', color=color)
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', color=color)

# %%
# CAV init
# init cost and density
ci_init_cost=[]
ci_init_density=[]
# end cost and density
ci_end_cost=[]
ci_end_density=[]

for i in vData[vehicleNum]['path_cav_init']['path']:
    ci_init_cost.append(i['init_cost'])
    ci_init_density.append(i['init_density'])
    ci_end_cost.append(i['end_cost'])
    ci_end_density.append(i['end_density'])

# %%
ci_total_init_cost=0
ci_total_init_density=0
ci_total_end_cost=0
ci_total_end_density=0

ci_total_init_cost = sum(ci_init_cost)
ci_total_init_density = sum(ci_init_density)
qi_total_end_cost = sum(ci_end_cost)
ci_total_end_density = sum(ci_end_density)

# %%
# end state
# CAV init
# init cost and density
ce_init_cost=[]
ce_init_density=[]
# end cost and density
ce_end_cost=[]
ce_end_density=[]

for i in vData[vehicleNum]['path_cav_end']['path']:
    ce_init_cost.append(i['init_cost'])
    ce_init_density.append(i['init_density'])
    ce_end_cost.append(i['end_cost'])
    ce_end_density.append(i['end_density'])

# %%
ce_total_init_cost=0
ce_total_init_density=0
ce_total_end_cost=0
ce_total_end_density=0


ce_total_init_cost = sum(ci_init_cost)
ce_total_init_density = sum(ci_init_density)
qe_total_end_cost = sum(ci_end_cost)
ce_total_end_density = sum(ci_end_density)

# %%
# create a table
cav_table=pd.DataFrame({
    "State": ["Initial", "Final"],
    "Cost":[ci_total_init_cost,ci_total_end_cost],
    "Density":[ci_total_init_density,ci_total_end_density]
})
print(cav_table)
# Out:
#      State   Cost  Density
# 0  Initial  103.0      4.0
# 1    Final    0.0      0.0

# %%
# comparing end cost and densities of ci and ce table
comp_table=pd.DataFrame({
    "State": ["Initial path", "Final path"],
    "Cost":[ci_total_init_cost,ce_total_end_cost],
    "Density":[ci_total_init_density,ce_total_end_density]
})
print(comp_table)
# Out:
#           State   Cost  Density
# 0  Initial path  103.0      4.0
# 1    Final path    0.0      0.0

# %%
# CAv separate

# %%
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plotPath(vData[vehicleNum]['path_cav_init']['path'],'red','orange')
# Out:
# {'id': 23, 'init_cost': 3.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}
# {'id': 21, 'init_cost': 33.0, 'end_cost': 0.0, 'init_density': 0.0, 'end_density': 0.0}
# {'id': 12, 'init_cost': 48.0, 'end_cost': 0.0, 'init_density': 2.0, 'end_density': 0.0}
# {'id': 6, 'init_cost': 17.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}
# {'id': 4, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 1.0, 'end_density': 0.0}
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', color=color)
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', color=color)

# %%
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plotPath(vData[vehicleNum]['path_cav_end']['path'],'blue','green')
# Out:
# {'id': 23, 'init_cost': 3.0, 'end_cost': 0.022577127441763878, 'init_density': 0.0, 'end_density': 1.0}
# {'id': 12, 'init_cost': 48.0, 'end_cost': 0.2668083906173706, 'init_density': 1.0, 'end_density': 3.0}
# {'id': 6, 'init_cost': 17.0, 'end_cost': 0.026082603260874748, 'init_density': 0.0, 'end_density': 2.0}
# {'id': 4, 'init_cost': 2.0, 'end_cost': 0.0, 'init_density': 4.0, 'end_density': 0.0}
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(x, y, 'b-', color=color)
# C:\Users\hutto\AppData\Local\Temp\ipykernel_19908\12810541.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', color=color)

# %%
# Metric

# %%
# CAV init
# init cost and density
ci_init_cost=[]
ci_init_density=[]
# end cost and density
ci_end_cost=[]
ci_end_density=[]

for i in vData[vehicleNum]['path_cav_init']['path']:
    ci_init_cost.append(i['init_cost'])
    ci_init_density.append(i['init_density'])
    ci_end_cost.append(i['end_cost'])
    ci_end_density.append(i['end_density'])

# %%
total_init_cost=0
total_init_density=0
total_end_cost=0
total_end_density=0
total_init_cost = sum(init_cost)
total_init_density = sum(init_density)
total_end_cost = sum(end_cost)
total_end_density = sum(end_density)

norm_table=pd.DataFrame({
    "State": ["Initial", "Final"],
    "Cost":[total_init_cost,total_end_cost],
    "Density":[total_init_density,total_end_density]
})
#print table
print(norm_table)
# Out:
#      State        Cost  Density
# 0  Initial  103.000000      5.0
# 1    Final    0.515149      5.0
